# %%
# %run 01_clean_provider.py
# Out:
# [paths] NH_ZIP_DIR=C:\Users\Owner\OneDrive\NursingHomeData\nh-compare
# [paths] PROV_DIR  =C:\Users\Owner\OneDrive\NursingHomeData\provider-info-files
# [paths] INTERIM   =C:\Repositories\white-bowblis-nhmc\data\interim
# [save] provider_info_2017_01.csv  rows=15,652
# [save] provider_info_2017_02.csv  rows=15,655
# [save] provider_info_2017_03.csv  rows=15,664
# [save] provider_info_2017_04.csv  rows=15,659
# [save] provider_info_2017_05.csv  rows=15,662
# [save] provider_info_2017_06.csv  rows=15,667
# [save] provider_info_2017_08.csv  rows=15,672
# [save] provider_info_2017_07.csv  rows=15,676
# [save] provider_info_2017_09.csv  rows=15,661
# [save] provider_info_2017_10.csv  rows=15,660
# [save] provider_info_2017_11.csv  rows=15,654
# [save] provider_info_2017_12.csv  rows=15,646
# [save] provider_info_2018_01.csv  rows=15,646
# [save] provider_info_2018_02.csv  rows=15,650
# [save] provider_info_2018_03.csv  rows=15,647
# [save] provider_info_2018_04.csv  rows=15,636
# ...

# %%
# %run 02_clean_pbj_nurse.py
# Out:
# [paths] RAW_DIR=C:\Users\Owner\OneDrive\NursingHomeData
# [paths] PBJ_DIR=C:\Users\Owner\OneDrive\NursingHomeData\pbj-nurse
# [paths] OUT_FP=C:\Repositories\white-bowblis-nhmc\data\interim\pbj_nurse.csv
# [scan] 33 files found
# [ok] pbj_nurse_2017_Q1.csv: 41,787 rows
# [ok] pbj_nurse_2017_Q2.csv: 41,952 rows
# [ok] pbj_nurse_2017_Q3.csv: 43,431 rows
# [ok] pbj_nurse_2017_Q4.csv: 42,426 rows
# [ok] pbj_nurse_2018_Q1.csv: 44,031 rows
# [ok] pbj_nurse_2018_Q2.csv: 43,986 rows
# [ok] pbj_nurse_2018_Q3.csv: 44,613 rows
# [ok] pbj_nurse_2018_Q4.csv: 44,748 rows
# [ok] pbj_nurse_2019_Q1.csv: 45,174 rows
# [ok] pbj_nurse_2019_Q2.csv: 45,060 rows
# [ok] pbj_nurse_2019_Q3.csv: 44,949 rows
# [ok] pbj_nurse_2019_Q4.csv: 44,907 rows
# [ok] pbj_nurse_2020_Q1.csv: 36,402 rows
# [ok] pbj_nurse_2020_Q2.csv: 44,289 rows
# [ok] pbj_nurse_2020_Q3.csv: 44,346 rows
# [ok] pbj_nurse_2020_Q4.csv: 44,064 rows
# [ok] pbj_nurse_2021_Q1.csv: 44,571 rows
# [ok] pbj_nurse_2021_Q2.csv: 44,436 rows
# ...

# %%
# %run 03_clean_ownership.py
# Out:
# [paths] NH_ZIP_DIR=C:\Users\Owner\OneDrive\NursingHomeData\nh-compare
# [paths] OWN_DIR=C:\Users\Owner\OneDrive\NursingHomeData\ownership-files
# [paths] INTERIM=C:\Repositories\white-bowblis-nhmc\data\interim
# [2017-01] nh_archive_01_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_01.csv
# [2017-02] nh_archive_02_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_02.csv
# [2017-03] nh_archive_03_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_03.csv
# [2017-04] nh_archive_04_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_04.csv
# [2017-05] nh_archive_05_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_05.csv
# [2017-06] nh_archive_06_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_06.csv
# [2017-08] nh_archive_08_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_08.csv
# [2017-07] nh_archive_07_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_07.csv
# [2017-09] nh_archive_09_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_09.csv
# ...

# %%
# %run 04_chow.py
# Out:
# [save] signatures long → C:\Repositories\white-bowblis-nhmc\data\interim\facility_signatures_long.csv  rows=38,239
# [save] signatures wide → C:\Repositories\white-bowblis-nhmc\data\interim\facility_signatures_wide_preview.csv  rows=13,955
# [saved] ownership CHOWs → C:\Repositories\white-bowblis-nhmc\data\interim\chow_nh_compare.csv  (rows=13,955)
# [saved] MCR CHOWs → C:\Repositories\white-bowblis-nhmc\data\interim\chow_mcr.csv  (rows=15,157)
# [saved] merged CHOWs  → C:\Repositories\white-bowblis-nhmc\data\interim\chow.csv  (rows=13,585)

# %%
# %run 05_mcr.py
# Out:
# [paths] RAW_DIR=C:\Users\Owner\OneDrive\NursingHomeData
# [paths] MCR_DIR=C:\Users\Owner\OneDrive\NursingHomeData\medicare-cost-reports
# [out]   C:\Repositories\white-bowblis-nhmc\data\interim\mcr.csv
# [read] mcr_flatfile_2016.sas7bdat rows=15,103 cols=12
# [read] mcr_flatfile_2017.sas7bdat rows=15,429 cols=12
# [read] mcr_flatfile_2018.sas7bdat rows=15,129 cols=12
# [read] mcr_flatfile_2019.sas7bdat rows=15,183 cols=12
# [read] mcr_flatfile_2020.sas7bdat rows=14,949 cols=12
# [read] mcr_flatfile_2021.sas7bdat rows=15,071 cols=12
# [read] mcr_flatfile_2022.sas7bdat rows=14,973 cols=12
# [read] mcr_flatfile_2023.sas7bdat rows=14,933 cols=12
# [read] mcr_flatfile_2024.sas7bdat rows=11,553 cols=12
# [beds corrections] updated FY rows: 11
# [save] controls → C:\Repositories\white-bowblis-nhmc\data\interim\mcr.csv  rows=1,510,717  CCNs=15,157
# cms_certification_number quarter year_month  pct_medicare  pct_medicaid  num_beds  occupancy_rate urban  chain state  non_profit  government
# ...

# %%
# %run 06_panel.py
# Out:
# [paths] provider=True  pbj=True  mcr=True  chow=True
# [spec]  SPEC_NAME=date_mcr  EVENT_DATE_SOURCE=mcr  EVENT_SHIFT_MONTHS=0
# [out]   pbj=C:\Repositories\white-bowblis-nhmc\data\clean\pbj_panel_date_mcr.csv
# [out]   analytical=C:\Repositories\white-bowblis-nhmc\data\clean\analytical_panel_date_mcr.csv
# [out]   final_panel=C:\Repositories\white-bowblis-nhmc\data\clean\panel_date_mcr.csv
# [chow] CCNs passing (0/0 or 1/1 within 6m): 7,880
# [save] PBJ panel (date_mcr) → C:\Repositories\white-bowblis-nhmc\data\clean\pbj_panel_date_mcr.csv rows=672,301 cols=65
# [filter] drop rows with NaN in any HPPD: 672,301 -> 641,644
# [filter] drop implausible HPPD: 641,644 -> 636,041  (joint_zero=1,017, total<1.5=4,885, total>12=162, cna>5.25=380)
# [filter] drop beds < 15: 636,041 -> 635,732
# [filter] drop 'provider_resides_in_hospital'==1: 635,732 -> 632,231
# [done] saved analytical panel (date_mcr) → C:\Repositories\white-bowblis-nhmc\data\clean\analytical_panel_date_mcr.csv
# ...
