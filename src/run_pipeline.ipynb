# %%
# %run 01_clean_provider.py
# Out:
# [paths] NH_ZIP_DIR=C:\Users\Owner\OneDrive\NursingHomeData\nh-compare
# [paths] PROV_DIR  =C:\Users\Owner\OneDrive\NursingHomeData\provider-info-files
# [paths] INTERIM   =C:\Repositories\white-bowblis-nhmc\data\interim
# [flags] RUN_EXTRACT=False, RUN_COMBINE=True, RUN_BUILD_QUARTERLY=True
# [skip] extraction step skipped
# [save] combined provider panel → C:\Repositories\white-bowblis-nhmc\data\interim\provider.csv  (1,468,217 rows)
# [qa] monthly_files=102, failed_reads=0, rows_before=3,087,480, rows_after_required=1,543,740, rows_after_dedup=1,468,217, unique_ccn=16,405, missing_beds_prov=2, missing_case_mix_total=158,972
# [save] quarterly provider panel → C:\Repositories\white-bowblis-nhmc\data\interim\provider_quarterly.csv  (535,315 rows)
# [qa-quarterly] unique_ccn=16,405, missing_beds_prov=0, missing_case_mix_total=60,240

# %%
# %run 02_clean_pbj_nurse.py
# Out:
# [paths] PBJ_DIR=C:\Users\Owner\OneDrive\NursingHomeData\pbj-nurse
# [paths] OUT_FP=C:\Repositories\white-bowblis-nhmc\data\interim\pbj_nurse.csv
# [paths] OUT_FP_QUARTERLY=C:\Repositories\white-bowblis-nhmc\data\interim\pbj_nurse_quarterly.csv
# [flags] RUN_BUILD_MONTHLY=False, RUN_BUILD_QUARTERLY=True
# [skip] monthly rebuild skipped
# [qa-quarterly] light monthly validity cleaning: 1,444,110 -> 1,444,110
# [saved] quarterly pbj nurse panel → C:\Repositories\white-bowblis-nhmc\data\interim\pbj_nurse_quarterly.csv (rows=481,370)
# [qa-quarterly] unique_ccn=16,119, missing_rn_hprd=0, missing_total_hprd=0, partial_qtrs=0, low_coverage_qtrs=725, implausible_hprd_qtrs=3,046, invalid_qtrs=0

# %%
# %run 03_clean_ownership.py
# Out:
# [paths] NH_ZIP_DIR=C:\Users\Owner\OneDrive\NursingHomeData\nh-compare
# [paths] OWN_DIR=C:\Users\Owner\OneDrive\NursingHomeData\ownership-files
# [paths] INTERIM=C:\Repositories\white-bowblis-nhmc\data\interim
# [2017-01] nh_archive_01_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_01.csv
# [2017-02] nh_archive_02_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_02.csv
# [2017-03] nh_archive_03_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_03.csv
# [2017-04] nh_archive_04_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_04.csv
# [2017-05] nh_archive_05_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_05.csv
# [2017-06] nh_archive_06_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_06.csv
# [2017-08] nh_archive_08_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_08.csv
# [2017-07] nh_archive_07_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_07.csv
# [2017-09] nh_archive_09_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_09.csv
# [2017-10] nh_archive_10_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_10.csv
# [2017-11] nh_archive_11_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_11.csv
# [2017-12] nh_archive_12_2017.zip → Ownership_Download.csv  ⇒  ownership_2017_12.csv
# [2018-01] nh_archive_01_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_01.csv
# [2018-02] nh_archive_02_2018.zip → Ownership_Display.csv  ⇒  ownership_2018_02.csv
# [2018-03] nh_archive_03_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_03.csv
# [2018-04] nh_archive_04_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_04.csv
# [2018-05] nh_archive_05_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_05.csv
# [2018-06] nh_archive_06_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_06.csv
# [2018-07] nh_archive_07_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_07.csv
# [2018-08] nh_archive_08_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_08.csv
# [2018-09] nh_archive_09_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_09.csv
# [2018-10] nh_archive_10_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_10.csv
# [2018-11] nh_archive_11_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_11.csv
# [2018-12] nh_archive_12_2018.zip → Ownership_Download.csv  ⇒  ownership_2018_12.csv
# [2019-01] nh_archive_01_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_01.csv
# [2019-02] nh_archive_02_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_02.csv
# [2019-03] nh_archive_03_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_03.csv
# [2019-04] nh_archive_04_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_04.csv
# [2019-05] nh_archive_05_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_05.csv
# [2019-06] nh_archive_06_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_06.csv
# [2019-07] nh_archive_07_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_07.csv
# [2019-08] nh_archive_08_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_08.csv
# [2019-09] nh_archive_09_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_09.csv
# [2019-10] nh_archive_10_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_10.csv
# [2019-12] nh_archive_12_2019.zip → Ownership_Download.csv  ⇒  ownership_2019_12.csv
# [2020-01] nh_archive_01_2020.zip → Ownership_Download.csv  ⇒  ownership_2020_01.csv
# [2020-02] nh_archive_02_2020.zip → Ownership_Download.csv  ⇒  ownership_2020_02.csv
# [2020-03] nh_archive_03_2020.zip → Ownership_Download.csv  ⇒  ownership_2020_03.csv
# [2020-04] nh_archive_04_2020.zip → Ownership_Download.csv  ⇒  ownership_2020_04.csv
# [2020-05] nh_archive_05_2020.zip → Ownership_Download.csv  ⇒  ownership_2020_05.csv
# [2020-06] nh_archive_06_2020.zip → Ownership_Download.csv  ⇒  ownership_2020_06.csv
# [2020-07] nh_archive_07_2020.zip → Ownership_Download.csv  ⇒  ownership_2020_07.csv
# [2020-08] nursing_homes_including_rehab_services_archive_08_2020.zip → NH_Ownership_Aug2020.csv  ⇒  ownership_2020_08.csv
# [2020-09] nursing_homes_including_rehab_services_archive_09_2020.zip → NH_Ownership_Sep2020.csv  ⇒  ownership_2020_09.csv
# [2020-10] nursing_homes_including_rehab_services_archive_10_2020.zip → NH_Ownership.csv  ⇒  ownership_2020_10.csv
# [2020-11] nursing_homes_including_rehab_services_archive_11_2020.zip → NH_Ownership_Nov2020.csv  ⇒  ownership_2020_11.csv
# [2020-12] nursing_homes_including_rehab_services_archive_12_2020.zip → NH_Ownership_Nov2020.csv  ⇒  ownership_2020_12.csv
# [2021-01] nursing_homes_including_rehab_services_01_2021.zip → NH_Ownership_Jan2021.csv  ⇒  ownership_2021_01.csv
# [2021-02] nursing_homes_including_rehab_services_02_2021.zip → NH_Ownership_Feb2021.csv  ⇒  ownership_2021_02.csv
# [2021-03] nursing_homes_including_rehab_services_03_2021.zip → NH_Ownership_Mar2021.csv  ⇒  ownership_2021_03.csv
# [2021-04] nursing_homes_including_rehab_services_04_2021.zip → NH_Ownership_Apr2021.csv  ⇒  ownership_2021_04.csv
# [2021-05] nursing_homes_including_rehab_services_05_2021.zip → NH_Ownership_May2021.csv  ⇒  ownership_2021_05.csv
# [2021-06] nursing_homes_including_rehab_services_06_2021.zip → NH_Ownership_Jun2021.csv  ⇒  ownership_2021_06.csv
# [2021-07] nursing_homes_including_rehab_services_07_2021.zip → NH_Ownership_Jul2021.csv  ⇒  ownership_2021_07.csv
# [2021-08] nursing_homes_including_rehab_services_08_2021.zip → NH_Ownership_Aug2021.csv  ⇒  ownership_2021_08.csv
# [2021-09] nursing_homes_including_rehab_services_09_2021.zip → NH_Ownership_Sep2021.csv  ⇒  ownership_2021_09.csv
# [2021-10] nursing_homes_including_rehab_services_10_2021.zip → NH_Ownership_Oct2021.csv  ⇒  ownership_2021_10.csv
# [2021-11] nursing_homes_including_rehab_services_11_2021.zip → NH_Ownership_Oct2021.csv  ⇒  ownership_2021_11.csv
# [2021-12] nursing_homes_including_rehab_services_12_2021.zip → NH_Ownership_Nov2021.csv  ⇒  ownership_2021_12.csv
# [2022-01] nursing_homes_including_rehab_services_01_2022.zip → NH_Ownership_Jan2022.csv  ⇒  ownership_2022_01.csv
# [2022-02] nursing_homes_including_rehab_services_02_2022.zip → NH_Ownership_Feb2022.csv  ⇒  ownership_2022_02.csv
# [2022-03] nursing_homes_including_rehab_services_03_2022.zip → NH_Ownership_Mar2022.csv  ⇒  ownership_2022_03.csv
# [2022-04] nursing_homes_including_rehab_services_04_2022.zip → NH_Ownership_Apr2022.csv  ⇒  ownership_2022_04.csv
# [2022-05] nursing_homes_including_rehab_services_05_2022.zip → NH_Ownership_May2022.csv  ⇒  ownership_2022_05.csv
# [2022-06] nursing_homes_including_rehab_services_06_2022.zip → NH_Ownership_Jun2022.csv  ⇒  ownership_2022_06.csv
# [2022-07] nursing_homes_including_rehab_services_07_2022.zip → NH_Ownership_Jul2022.csv  ⇒  ownership_2022_07.csv
# [2022-08] nursing_homes_including_rehab_services_08_2022.zip → NH_Ownership_Aug2022.csv  ⇒  ownership_2022_08.csv
# [2022-09] nursing_homes_including_rehab_services_09_2022.zip → NH_Ownership_Sep2022.csv  ⇒  ownership_2022_09.csv
# [2022-10] nursing_homes_including_rehab_services_10_2022.zip → NH_Ownership_Oct2022.csv  ⇒  ownership_2022_10.csv
# [2022-11] nursing_homes_including_rehab_services_11_2022.zip → NH_Ownership_Oct2022.csv  ⇒  ownership_2022_11.csv
# [2022-12] nursing_homes_including_rehab_services_12_2022.zip → NH_Ownership_Nov2022.csv  ⇒  ownership_2022_12.csv
# [2023-01] nursing_homes_including_rehab_services_01_2023.zip → NH_Ownership_Jan2023.csv  ⇒  ownership_2023_01.csv
# [2023-02] nursing_homes_including_rehab_services_02_2023.zip → NH_Ownership_Feb2023.csv  ⇒  ownership_2023_02.csv
# [2023-03] nursing_homes_including_rehab_services_03_2023.zip → NH_Ownership_Mar2023.csv  ⇒  ownership_2023_03.csv
# [2023-04] nursing_homes_including_rehab_services_04_2023.zip → NH_Ownership_Apr2023.csv  ⇒  ownership_2023_04.csv
# [2023-05] nursing_homes_including_rehab_services_05_2023.zip → NH_Ownership_May2023.csv  ⇒  ownership_2023_05.csv
# [2023-06] nursing_homes_including_rehab_services_06_2023.zip → NH_Ownership_Jun2023.csv  ⇒  ownership_2023_06.csv
# [2023-07] nursing_homes_including_rehab_services_07_2023.zip → NH_Ownership_Jul2023.csv  ⇒  ownership_2023_07.csv
# [2023-08] nursing_homes_including_rehab_services_08_2023.zip → NH_Ownership_Aug2023.csv  ⇒  ownership_2023_08.csv
# [2023-09] nursing_homes_including_rehab_services_09_2023.zip → NH_Ownership_Sep2023.csv  ⇒  ownership_2023_09.csv
# [2023-10] nursing_homes_including_rehab_services_10_2023.zip → NH_Ownership_Oct2023.csv  ⇒  ownership_2023_10.csv
# [2023-11] nursing_homes_including_rehab_services_11_2023.zip → NH_Ownership_Oct2023.csv  ⇒  ownership_2023_11.csv
# [2023-12] nursing_homes_including_rehab_services_12_2023.zip → NH_Ownership_Nov2023.csv  ⇒  ownership_2023_12.csv
# [2024-01] nursing_homes_including_rehab_services_01_2024.zip → NH_Ownership_Jan2024.csv  ⇒  ownership_2024_01.csv
# [2024-02] nursing_homes_including_rehab_services_02_2024.zip → NH_Ownership_Feb2024.csv  ⇒  ownership_2024_02.csv
# [2024-03] nursing_homes_including_rehab_services_03_2024.zip → NH_Ownership_Mar2024.csv  ⇒  ownership_2024_03.csv
# [2024-04] nursing_homes_including_rehab_services_04_2024.zip → NH_Ownership_Apr2024.csv  ⇒  ownership_2024_04.csv
# [2024-05] nursing_homes_including_rehab_services_05_2024.zip → NH_Ownership_May2024.csv  ⇒  ownership_2024_05.csv
# [2024-06] nursing_homes_including_rehab_services_06_2024.zip → NH_Ownership_Jun2024.csv  ⇒  ownership_2024_06.csv
# [2024-07] nursing_homes_including_rehab_services_07_2024.zip → NH_Ownership_Jul2024.csv  ⇒  ownership_2024_07.csv
# [2024-08] nursing_homes_including_rehab_services_08_2024.zip → NH_Ownership_Aug2024.csv  ⇒  ownership_2024_08.csv
# [2024-09] nursing_homes_including_rehab_services_09_2024.zip → NH_Ownership_Sep2024.csv  ⇒  ownership_2024_09.csv
# [2024-10] nursing_homes_including_rehab_services_10_2024.zip → NH_Ownership_Oct2024.csv  ⇒  ownership_2024_10.csv
# [2024-11] nursing_homes_including_rehab_services_11_2024.zip → NH_Ownership_Oct2024.csv  ⇒  ownership_2024_11.csv
# [2024-12] nursing_homes_including_rehab_services_12_2024.zip → NH_Ownership_Nov2024.csv  ⇒  ownership_2024_12.csv
# [2025-02] nursing_homes_including_rehab_services_02_2025.zip → NH_Ownership_Feb2025.csv  ⇒  ownership_2025_02.csv
# [2025-03] nursing_homes_including_rehab_services_03_2025.zip → NH_Ownership_Mar2025.csv  ⇒  ownership_2025_03.csv
# [2025-04] nursing_homes_including_rehab_services_04_2025.zip → NH_Ownership_Apr2025.csv  ⇒  ownership_2025_04.csv
# [2025-05] nursing_homes_including_rehab_services_05_2025.zip → NH_Ownership_May2025.csv  ⇒  ownership_2025_05.csv
# [2025-06] nursing_homes_including_rehab_services_06_2025.zip → NH_Ownership_Jun2025.csv  ⇒  ownership_2025_06.csv
# [2025-07] nursing_homes_including_rehab_services_07_2025.zip → NH_Ownership_Jul2025.csv  ⇒  ownership_2025_07.csv
#
# [extract] extracted=101, skipped=0
# [rewrite] ownership_2017_01.csv  rows=57791
# [rewrite] ownership_2017_02.csv  rows=57051
# [rewrite] ownership_2017_03.csv  rows=57981
# [rewrite] ownership_2017_04.csv  rows=57952
# [rewrite] ownership_2017_05.csv  rows=57535
# [rewrite] ownership_2017_06.csv  rows=57483
# [rewrite] ownership_2017_07.csv  rows=57455
# [rewrite] ownership_2017_08.csv  rows=57420
# [rewrite] ownership_2017_09.csv  rows=57445
# [rewrite] ownership_2017_10.csv  rows=57396
# [rewrite] ownership_2017_11.csv  rows=57513
# [rewrite] ownership_2017_12.csv  rows=57485
# [rewrite] ownership_2018_01.csv  rows=56360
# [rewrite] ownership_2018_02.csv  rows=57217
# [rewrite] ownership_2018_03.csv  rows=55937
# [rewrite] ownership_2018_04.csv  rows=56973
# [rewrite] ownership_2018_05.csv  rows=57032
# [rewrite] ownership_2018_06.csv  rows=56873
# [rewrite] ownership_2018_07.csv  rows=56865
# [rewrite] ownership_2018_08.csv  rows=55847
# [rewrite] ownership_2018_09.csv  rows=56338
# [rewrite] ownership_2018_10.csv  rows=55437
# [rewrite] ownership_2018_11.csv  rows=56253
# [rewrite] ownership_2018_12.csv  rows=56082
# [rewrite] ownership_2019_01.csv  rows=56018
# [rewrite] ownership_2019_02.csv  rows=55646
# [rewrite] ownership_2019_03.csv  rows=55421
# [rewrite] ownership_2019_04.csv  rows=55090
# [rewrite] ownership_2019_05.csv  rows=54674
# [rewrite] ownership_2019_06.csv  rows=54233
# [rewrite] ownership_2019_07.csv  rows=54301
# [rewrite] ownership_2019_08.csv  rows=54250
# [rewrite] ownership_2019_09.csv  rows=53967
# [rewrite] ownership_2019_10.csv  rows=53763
# [rewrite] ownership_2019_12.csv  rows=53727
# [rewrite] ownership_2020_01.csv  rows=53429
# [rewrite] ownership_2020_02.csv  rows=53525
# [rewrite] ownership_2020_03.csv  rows=53688
# [rewrite] ownership_2020_04.csv  rows=53694
# [rewrite] ownership_2020_05.csv  rows=53638
# [rewrite] ownership_2020_06.csv  rows=53601
# [rewrite] ownership_2020_07.csv  rows=53557
# [rewrite] ownership_2020_08.csv  rows=53447
# [rewrite] ownership_2020_09.csv  rows=53180
# [rewrite] ownership_2020_10.csv  rows=53131
# [rewrite] ownership_2020_11.csv  rows=53151
# [rewrite] ownership_2020_12.csv  rows=53151
# [rewrite] ownership_2021_01.csv  rows=53053
# [rewrite] ownership_2021_02.csv  rows=52868
# [rewrite] ownership_2021_03.csv  rows=52691
# [rewrite] ownership_2021_04.csv  rows=52606
# [rewrite] ownership_2021_05.csv  rows=52649
# [rewrite] ownership_2021_06.csv  rows=52675
# [rewrite] ownership_2021_07.csv  rows=52456
# [rewrite] ownership_2021_08.csv  rows=50912
# [rewrite] ownership_2021_09.csv  rows=51903
# [rewrite] ownership_2021_10.csv  rows=51796
# [rewrite] ownership_2021_11.csv  rows=51796
# [rewrite] ownership_2021_12.csv  rows=51586
# [rewrite] ownership_2022_01.csv  rows=50986
# [rewrite] ownership_2022_02.csv  rows=50793
# [rewrite] ownership_2022_03.csv  rows=50765
# [rewrite] ownership_2022_04.csv  rows=50608
# [rewrite] ownership_2022_05.csv  rows=50719
# [rewrite] ownership_2022_06.csv  rows=50815
# [rewrite] ownership_2022_07.csv  rows=50735
# [rewrite] ownership_2022_08.csv  rows=50450
# [rewrite] ownership_2022_09.csv  rows=50302
# [rewrite] ownership_2022_10.csv  rows=50189
# [rewrite] ownership_2022_11.csv  rows=50189
# [rewrite] ownership_2022_12.csv  rows=50165
# [rewrite] ownership_2023_01.csv  rows=50204
# [rewrite] ownership_2023_02.csv  rows=50038
# [rewrite] ownership_2023_03.csv  rows=49880
# [rewrite] ownership_2023_04.csv  rows=49649
# [rewrite] ownership_2023_05.csv  rows=49576
# [rewrite] ownership_2023_06.csv  rows=49308
# [rewrite] ownership_2023_07.csv  rows=49298
# [rewrite] ownership_2023_08.csv  rows=49450
# [rewrite] ownership_2023_09.csv  rows=49352
# [rewrite] ownership_2023_10.csv  rows=49499
# [rewrite] ownership_2023_11.csv  rows=49499
# [rewrite] ownership_2023_12.csv  rows=49638
# [rewrite] ownership_2024_01.csv  rows=49095
# [rewrite] ownership_2024_02.csv  rows=49187
# [rewrite] ownership_2024_03.csv  rows=49273
# [rewrite] ownership_2024_04.csv  rows=49405
# [rewrite] ownership_2024_05.csv  rows=49403
# [rewrite] ownership_2024_06.csv  rows=49568
# [rewrite] ownership_2024_07.csv  rows=49785
# [rewrite] ownership_2024_08.csv  rows=49837
# [rewrite] ownership_2024_09.csv  rows=49907
# [rewrite] ownership_2024_10.csv  rows=49906
# [rewrite] ownership_2024_11.csv  rows=49906
# [rewrite] ownership_2024_12.csv  rows=49863
# [rewrite] ownership_2025_02.csv  rows=49624
# [rewrite] ownership_2025_03.csv  rows=49504
# [rewrite] ownership_2025_04.csv  rows=49263
# [rewrite] ownership_2025_05.csv  rows=49219
# [rewrite] ownership_2025_06.csv  rows=49225
# [rewrite] ownership_2025_07.csv  rows=49243
# [rewrite] ownership_combined.csv  rows=0
#
# [standardize] Rewrote 102 file(s).
# [filter-monthly] removed 67,094 row(s) and 623 unique CCN(s) (in-hospital months)
# [dedup-combined] removed 251,306 exact duplicate row(s) across all months
# [save] ownership panel → C:\Repositories\white-bowblis-nhmc\data\interim\ownership.csv  (5,011,914 rows)

# %%
# %run 04_chow.py
# Out:
# [save] signatures long → C:\Repositories\white-bowblis-nhmc\data\interim\facility_signatures_long.csv  rows=38,239
# [save] signatures wide → C:\Repositories\white-bowblis-nhmc\data\interim\facility_signatures_wide_preview.csv  rows=13,955
# [saved] ownership CHOWs → C:\Repositories\white-bowblis-nhmc\data\interim\chow_nh_compare.csv  (rows=13,955)
# [saved] MCR CHOWs → C:\Repositories\white-bowblis-nhmc\data\interim\chow_mcr.csv  (rows=15,157)
# [saved] merged CHOWs  → C:\Repositories\white-bowblis-nhmc\data\interim\chow.csv  (rows=13,585)

# %%
# %run 05_mcr.py
# Out:
# [paths] MCR_DIR=C:\Users\wrthj\OneDrive\NursingHomeData\medicare-cost-reports
# [out]   C:\Repositories\white-bowblis-nhmc\data\interim\mcr.csv
# [out]   C:\Repositories\white-bowblis-nhmc\data\interim\mcr_quarterly.csv
# [flags] RUN_BUILD_MONTHLY=True, RUN_BUILD_QUARTERLY=True
# [read] mcr_flatfile_2016.sas7bdat rows=15,103 cols=15
# [read] mcr_flatfile_2017.sas7bdat rows=15,429 cols=15
# [read] mcr_flatfile_2018.sas7bdat rows=15,129 cols=15
# [read] mcr_flatfile_2019.sas7bdat rows=15,183 cols=15
# [read] mcr_flatfile_2020.sas7bdat rows=14,949 cols=15
# [read] mcr_flatfile_2021.sas7bdat rows=15,071 cols=15
# [read] mcr_flatfile_2022.sas7bdat rows=14,973 cols=15
# [read] mcr_flatfile_2023.sas7bdat rows=14,933 cols=15
# [read] mcr_flatfile_2024.sas7bdat rows=11,553 cols=15
# [beds corrections] updated FY rows: 11
# [save] controls → C:\Repositories\white-bowblis-nhmc\data\interim\mcr.csv  rows=1,510,717  CCNs=15,157
# cms_certification_number quarter year_month  pct_medicare  pct_medicaid  avg_los_total  avg_los_medicare  avg_los_medicaid  num_beds  occupancy_rate urban  chain state  non_profit  government
#                   015009  2016Q3    2016/07     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2016Q3    2016/08     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2016Q3    2016/09     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2016Q4    2016/10     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2016Q4    2016/11     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2016Q4    2016/12     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2017Q1    2017/01     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2017Q1    2017/02     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2017Q1    2017/03     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
#                   015009  2017Q2    2017/04     12.038348     73.521081          27.56             24.29             27.54      57.0       88.238404   0.0      0    AL           0           0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File C:\Repositories\white-bowblis-nhmc\src\05_mcr.py:714
#     710         print("[skip] quarterly build skipped")
#     713 if __name__ == "__main__":
# --> 714     main()
#
# File C:\Repositories\white-bowblis-nhmc\src\05_mcr.py:708, in main()
#     705     print("[skip] monthly rebuild skipped")
#     707 if RUN_BUILD_QUARTERLY:
# --> 708     build_quarterly_from_monthly()
#     709 else:
#     710     print("[skip] quarterly build skipped")
#
# File C:\Repositories\white-bowblis-nhmc\src\05_mcr.py:590, in build_quarterly_from_monthly()
#     582 monthly = monthly.sort_values(
#     583     ["cms_certification_number", "year", "quarter_num", "_ord"],
#     584     kind="mergesort"
#     585 )
#     587 grp = ["cms_certification_number", "year", "quarter"]
#     589 qtr = (
# --> 590     monthly.groupby(grp, sort=False)
#     591     .agg(
#     592         pct_medicare=("pct_medicare", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     593         pct_medicaid=("pct_medicaid", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     594         avg_los_total=("avg_los_total", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     595         avg_los_medicare=("avg_los_medicare", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     596         avg_los_medicaid=("avg_los_medicaid", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     597         num_beds=("num_beds", lambda s: mode_with_last_tiebreak(s, round_digits=0)),
#     598         occupancy_rate=("occupancy_rate", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     599         urban=("urban", mode_with_last_tiebreak),
#     600         chain=("chain", mode_with_last_tiebreak),
#     601         state=("state", mode_with_last_tiebreak),
#     602         non_profit=("non_profit", mode_with_last_tiebreak),
#     603         government=("government", mode_with_last_tiebreak),
#     604
#     605         months_observed_in_quarter=("year_month", "nunique"),
#     606         last_year_month_in_quarter=("year_month", "last"),
#     607
#     608         pct_medicare_mode_share=("pct_medicare", lambda s: mode_share(s, round_digits=4)),
#     609         pct_medicaid_mode_share=("pct_medicaid", lambda s: mode_share(s, round_digits=4)),
#     610         avg_los_total_mode_share=("avg_los_total", lambda s: mode_share(s, round_digits=4)),
#     611         avg_los_medicare_mode_share=("avg_los_medicare", lambda s: mode_share(s, round_digits=4)),
#     612         avg_los_medicaid_mode_share=("avg_los_medicaid", lambda s: mode_share(s, round_digits=4)),
#     613         num_beds_mode_share=("num_beds", lambda s: mode_share(s, round_digits=0)),
#     614         occupancy_rate_mode_share=("occupancy_rate", lambda s: mode_share(s, round_digits=4)),
#     615         urban_mode_share=("urban", mode_share),
#     616         chain_mode_share=("chain", mode_share),
#     617         state_mode_share=("state", mode_share),
#     618         non_profit_mode_share=("non_profit", mode_share),
#     619         government_mode_share=("government", mode_share),
#     620
#     621         pct_medicare_disagreement=("pct_medicare", lambda s: disagreement_flag(s, round_digits=4)),
#     622         pct_medicaid_disagreement=("pct_medicaid", lambda s: disagreement_flag(s, round_digits=4)),
#     623         avg_los_total_disagreement=("avg_los_total", lambda s: disagreement_flag(s, round_digits=4)),
#     624         avg_los_medicare_disagreement=("avg_los_medicare", lambda s: disagreement_flag(s, round_digits=4)),
#     625         avg_los_medicaid_disagreement=("avg_los_medicaid", lambda s: disagreement_flag(s, round_digits=4)),
#     626         num_beds_disagreement=("num_beds", lambda s: disagreement_flag(s, round_digits=0)),
#     627         occupancy_rate_disagreement=("occupancy_rate", lambda s: disagreement_flag(s, round_digits=4)),
#     628         urban_disagreement=("urban", disagreement_flag),
#     629         chain_disagreement=("chain", disagreement_flag),
#     630         state_disagreement=("state", disagreement_flag),
#     631         non_profit_disagreement=("non_profit", disagreement_flag),
#     632         government_disagreement=("government", disagreement_flag),
#     633     )
#     634     .reset_index()
#     635 )
#     637 # cleanup types
#     638 for col in ["pct_medicare", "pct_medicaid", "num_beds", "occupancy_rate"]:
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\generic.py:1432, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1429     kwargs["engine_kwargs"] = engine_kwargs
#    1431 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1432 result = op.agg()
#    1433 if not is_dict_like(func) and result is not None:
#    1434     # GH #52849
#    1435     if not self.as_index and is_list_like(func):
#
# File ~\miniconda3\Lib\site-packages\pandas\core\apply.py:190, in Apply.agg(self)
#     187     return self.apply_str()
#     189 if is_dict_like(func):
# --> 190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
#     193     return self.agg_list_like()
#
# File ~\miniconda3\Lib\site-packages\pandas\core\apply.py:423, in Apply.agg_dict_like(self)
#     415 def agg_dict_like(self) -> DataFrame | Series:
#     416     """
#     417     Compute aggregation in the case of a dict-like argument.
#     418
#    (...)    421     Result of aggregation.
#     422     """
# --> 423     return self.agg_or_apply_dict_like(op_name="agg")
#
# File ~\miniconda3\Lib\site-packages\pandas\core\apply.py:1608, in GroupByApply.agg_or_apply_dict_like(self, op_name)
#    1603     kwargs.update({"engine": engine, "engine_kwargs": engine_kwargs})
#    1605 with com.temp_setattr(
#    1606     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1607 ):
# -> 1608     result_index, result_data = self.compute_dict_like(
#    1609         op_name, selected_obj, selection, kwargs
#    1610     )
#    1611 result = self.wrap_results_dict_like(selected_obj, result_index, result_data)
#    1612 return result
#
# File ~\miniconda3\Lib\site-packages\pandas\core\apply.py:497, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     493         results += key_data
#     494 else:
#     495     # key used for column selection and output
#     496     results = [
# --> 497         getattr(obj._gotitem(key, ndim=1), op_name)(how, **kwargs)
#     498         for key, how in func.items()
#     499     ]
#     500     keys = list(func.keys())
#     502 return keys, results
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\generic.py:257, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     255 kwargs["engine"] = engine
#     256 kwargs["engine_kwargs"] = engine_kwargs
# --> 257 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     258 if relabeling:
#     259     # columns is not narrowed by mypy from relabeling flag
#     260     assert columns is not None  # for mypy
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\generic.py:362, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     360     for idx, (name, func) in enumerate(arg):
#     361         key = base.OutputKey(label=name, position=idx)
# --> 362         results[key] = self.aggregate(func, *args, **kwargs)
#     364 if any(isinstance(x, DataFrame) for x in results.values()):
#     365     from pandas import concat
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\generic.py:291, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     283     return self.obj._constructor(
#     284         [],
#     285         name=self.obj.name,
#     286         index=self._grouper.result_index,
#     287         dtype=obj.dtype,
#     288     )
#     290 if self._grouper.nkeys > 1:
# --> 291     return self._python_agg_general(func, *args, **kwargs)
#     293 try:
#     294     return self._python_agg_general(func, *args, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\generic.py:327, in SeriesGroupBy._python_agg_general(self, func, *args, **kwargs)
#     324 f = lambda x: func(x, *args, **kwargs)
#     326 obj = self._obj_with_exclusions
# --> 327 result = self._grouper.agg_series(obj, f)
#     328 res = obj._constructor(result, name=obj.name)
#     329 return self._wrap_aggregated_output(res)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     857 if not isinstance(obj._values, np.ndarray):
#     858     # we can preserve a little bit more aggressively with EA dtype
#     859     #  because maybe_cast_pointwise_result will do a try/except
#     860     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     861     #  is sufficiently strict that it casts appropriately.
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     867 if preserve_dtype:
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     882 splitter = self._get_splitter(obj, axis=0)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#     888     if not initialized:
#     889         # We only do this validation on the first iteration
#
# File ~\miniconda3\Lib\site-packages\pandas\core\groupby\generic.py:324, in SeriesGroupBy._python_agg_general.<locals>.<lambda>(x)
#     322     alias = com._builtin_table_alias[func]
#     323     warn_alias_replacement(self, orig_func, alias)
# --> 324 f = lambda x: func(x, *args, **kwargs)
#     326 obj = self._obj_with_exclusions
#     327 result = self._grouper.agg_series(obj, f)
#
# File C:\Repositories\white-bowblis-nhmc\src\05_mcr.py:594, in build_quarterly_from_monthly.<locals>.<lambda>(s)
#     582 monthly = monthly.sort_values(
#     583     ["cms_certification_number", "year", "quarter_num", "_ord"],
#     584     kind="mergesort"
#     585 )
#     587 grp = ["cms_certification_number", "year", "quarter"]
#     589 qtr = (
#     590     monthly.groupby(grp, sort=False)
#     591     .agg(
#     592         pct_medicare=("pct_medicare", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     593         pct_medicaid=("pct_medicaid", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
# --> 594         avg_los_total=("avg_los_total", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     595         avg_los_medicare=("avg_los_medicare", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     596         avg_los_medicaid=("avg_los_medicaid", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     597         num_beds=("num_beds", lambda s: mode_with_last_tiebreak(s, round_digits=0)),
#     598         occupancy_rate=("occupancy_rate", lambda s: mode_with_last_tiebreak(s, round_digits=4)),
#     599         urban=("urban", mode_with_last_tiebreak),
#     600         chain=("chain", mode_with_last_tiebreak),
#     601         state=("state", mode_with_last_tiebreak),
#     602         non_profit=("non_profit", mode_with_last_tiebreak),
#     603         government=("government", mode_with_last_tiebreak),
#     604
#     605         months_observed_in_quarter=("year_month", "nunique"),
#     606         last_year_month_in_quarter=("year_month", "last"),
#     607
#     608         pct_medicare_mode_share=("pct_medicare", lambda s: mode_share(s, round_digits=4)),
#     609         pct_medicaid_mode_share=("pct_medicaid", lambda s: mode_share(s, round_digits=4)),
#     610         avg_los_total_mode_share=("avg_los_total", lambda s: mode_share(s, round_digits=4)),
#     611         avg_los_medicare_mode_share=("avg_los_medicare", lambda s: mode_share(s, round_digits=4)),
#     612         avg_los_medicaid_mode_share=("avg_los_medicaid", lambda s: mode_share(s, round_digits=4)),
#     613         num_beds_mode_share=("num_beds", lambda s: mode_share(s, round_digits=0)),
#     614         occupancy_rate_mode_share=("occupancy_rate", lambda s: mode_share(s, round_digits=4)),
#     615         urban_mode_share=("urban", mode_share),
#     616         chain_mode_share=("chain", mode_share),
#     617         state_mode_share=("state", mode_share),
#     618         non_profit_mode_share=("non_profit", mode_share),
#     619         government_mode_share=("government", mode_share),
#     620
#     621         pct_medicare_disagreement=("pct_medicare", lambda s: disagreement_flag(s, round_digits=4)),
#     622         pct_medicaid_disagreement=("pct_medicaid", lambda s: disagreement_flag(s, round_digits=4)),
#     623         avg_los_total_disagreement=("avg_los_total", lambda s: disagreement_flag(s, round_digits=4)),
#     624         avg_los_medicare_disagreement=("avg_los_medicare", lambda s: disagreement_flag(s, round_digits=4)),
#     625         avg_los_medicaid_disagreement=("avg_los_medicaid", lambda s: disagreement_flag(s, round_digits=4)),
#     626         num_beds_disagreement=("num_beds", lambda s: disagreement_flag(s, round_digits=0)),
#     627         occupancy_rate_disagreement=("occupancy_rate", lambda s: disagreement_flag(s, round_digits=4)),
#     628         urban_disagreement=("urban", disagreement_flag),
#     629         chain_disagreement=("chain", disagreement_flag),
#     630         state_disagreement=("state", disagreement_flag),
#     631         non_profit_disagreement=("non_profit", disagreement_flag),
#     632         government_disagreement=("government", disagreement_flag),
#     633     )
#     634     .reset_index()
#     635 )
#     637 # cleanup types
#     638 for col in ["pct_medicare", "pct_medicaid", "num_beds", "occupancy_rate"]:
#
# File C:\Repositories\white-bowblis-nhmc\src\05_mcr.py:130, in mode_with_last_tiebreak(s, round_digits)
#     127 else:
#     128     s_work = s2.copy()
# --> 130 counts = s_work.value_counts(dropna=True)
#     131 if counts.empty:
#     132     return pd.NA
#
# File ~\miniconda3\Lib\site-packages\pandas\core\base.py:1010, in IndexOpsMixin.value_counts(self, normalize, sort, ascending, bins, dropna)
#     923 @final
#     924 def value_counts(
#     925     self,
#    (...)    930     dropna: bool = True,
#     931 ) -> Series:
#     932     """
#     933     Return a Series containing counts of unique values.
#     934
#    (...)   1008     Name: count, dtype: int64
#    1009     """
# -> 1010     return algorithms.value_counts_internal(
#    1011         self,
#    1012         sort=sort,
#    1013         ascending=ascending,
#    1014         normalize=normalize,
#    1015         bins=bins,
#    1016         dropna=dropna,
#    1017     )
#
# File ~\miniconda3\Lib\site-packages\pandas\core\algorithms.py:951, in value_counts_internal(values, sort, ascending, normalize, bins, dropna)
#     940             warnings.warn(
#     941                 # GH#56161
#     942                 "The behavior of value_counts with object-dtype is deprecated. "
#    (...)    947                 stacklevel=find_stack_level(),
#     948             )
#     949         idx.name = index_name
# --> 951         result = Series(counts, index=idx, name=name, copy=False)
#     953 if sort:
#     954     result = result.sort_values(ascending=ascending)
#
# File ~\miniconda3\Lib\site-packages\pandas\core\series.py:584, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     582         data = data.copy()
#     583 else:
# --> 584     data = sanitize_array(data, index, dtype, copy)
#     586     manager = _get_option("mode.data_manager", silent=True)
#     587     if manager == "block":
#
# File ~\miniconda3\Lib\site-packages\pandas\core\construction.py:566, in sanitize_array(data, index, dtype, copy, allow_2d)
#     563     data = range_to_ndarray(data)
#     564     copy = False
# --> 566 if not is_list_like(data):
#     567     if index is None:
#     568         raise ValueError("index must be specified when data is not list-like")
#
# KeyboardInterrupt:

# %%
# %run 06_panel.py
# Out:
# [paths] provider=True  pbj=True  mcr=True  chow=True
# [out]   staffing_panel=C:\Repositories\white-bowblis-nhmc\data\clean\staffing_panel.csv
# [chow] CCNs passing (0/0 or 1/1 within 6m): 7,880
# [filter] drop AK/HI: 672,301 -> 670,328
# C:\Repositories\white-bowblis-nhmc\src\06_panel.py:217: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return panel.groupby(group_key, group_keys=False, observed=True).apply(_apply)
# C:\Repositories\white-bowblis-nhmc\src\06_panel.py:217: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return panel.groupby(group_key, group_keys=False, observed=True).apply(_apply)
# [filter] drop rows with NaN in any HPRD: 670,328 -> 639,812
# [filter] drop implausible HPRD: 639,812 -> 634,220  (joint_zero=1,016, total<1.5=4,884, total>12=162, cna>5.25=370)
# [filter] drop beds < 15: 634,220 -> 633,911
# [filter] drop 'provider_resides_in_hospital'==1: 633,911 -> 630,420
# [done] saved staffing panel → C:\Repositories\white-bowblis-nhmc\data\clean\staffing_panel.csv rows=630,420 cols=64

# %%
# %run quality-metrics.py
# Out:
# [paths] NH_ZIP_DIR=C:\Users\Owner\OneDrive\NursingHomeData\nh-compare
# [paths] QM_DIR    =C:\Users\Owner\OneDrive\NursingHomeData\quality-measures
# [paths] INTERIM   =C:\Repositories\white-bowblis-nhmc\data\interim
# [2017-01] nh_archive_01_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_01.csv
# [2017-02] nh_archive_02_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_02.csv
# [2017-03] nh_archive_03_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_03.csv
# [2017-04] nh_archive_04_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_04.csv
# [2017-05] nh_archive_05_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_05.csv
# [2017-06] nh_archive_06_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_06.csv
# [2017-08] nh_archive_08_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_08.csv
# [2017-07] nh_archive_07_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_07.csv
# [2017-09] nh_archive_09_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_09.csv
# [2017-10] nh_archive_10_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_10.csv
# [2017-11] nh_archive_11_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_11.csv
# [2017-12] nh_archive_12_2017.zip -> QualityMsrMDS_Download.csv => quality_measures_2017_12.csv
# [2018-01] nh_archive_01_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_01.csv
# [2018-02] nh_archive_02_2018.zip -> QualityMsrMDS_Display.csv => quality_measures_2018_02.csv
# [2018-03] nh_archive_03_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_03.csv
# [2018-04] nh_archive_04_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_04.csv
# [2018-05] nh_archive_05_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_05.csv
# [2018-06] nh_archive_06_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_06.csv
# [2018-07] nh_archive_07_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_07.csv
# [2018-08] nh_archive_08_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_08.csv
# [2018-09] nh_archive_09_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_09.csv
# [2018-10] nh_archive_10_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_10.csv
# [2018-11] nh_archive_11_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_11.csv
# [2018-12] nh_archive_12_2018.zip -> QualityMsrMDS_Download.csv => quality_measures_2018_12.csv
# [2019-01] nh_archive_01_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_01.csv
# [2019-02] nh_archive_02_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_02.csv
# [2019-03] nh_archive_03_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_03.csv
# [2019-04] nh_archive_04_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_04.csv
# [2019-05] nh_archive_05_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_05.csv
# [2019-06] nh_archive_06_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_06.csv
# [2019-07] nh_archive_07_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_07.csv
# [2019-08] nh_archive_08_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_08.csv
# [2019-09] nh_archive_09_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_09.csv
# [2019-10] nh_archive_10_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_10.csv
# [2019-12] nh_archive_12_2019.zip -> QualityMsrMDS_Download.csv => quality_measures_2019_12.csv
# [2020-01] nh_archive_01_2020.zip -> QualityMsrMDS_Download.csv => quality_measures_2020_01.csv
# [2020-02] nh_archive_02_2020.zip -> QualityMsrMDS_Download.csv => quality_measures_2020_02.csv
# [2020-03] nh_archive_03_2020.zip -> QualityMsrMDS_Download.csv => quality_measures_2020_03.csv
# [2020-04] nh_archive_04_2020.zip -> QualityMsrMDS_Download.csv => quality_measures_2020_04.csv
# [2020-05] nh_archive_05_2020.zip -> QualityMsrMDS_Download.csv => quality_measures_2020_05.csv
# [2020-06] nh_archive_06_2020.zip -> QualityMsrMDS_Download.csv => quality_measures_2020_06.csv
# [2020-07] nh_archive_07_2020.zip -> QualityMsrMDS_Download.csv => quality_measures_2020_07.csv
# [2020-08] nursing_homes_including_rehab_services_archive_08_2020.zip -> NH_QualityMsr_MDS_Aug2020.csv => quality_measures_2020_08.csv
# [2020-09] nursing_homes_including_rehab_services_archive_09_2020.zip -> NH_QualityMsr_MDS_Sep2020.csv => quality_measures_2020_09.csv
# [2020-10] nursing_homes_including_rehab_services_archive_10_2020.zip -> NH_QualityMsr_MDS.csv => quality_measures_2020_10.csv
# [2020-11] nursing_homes_including_rehab_services_archive_11_2020.zip -> NH_QualityMsr_MDS_Nov2020.csv => quality_measures_2020_11.csv
# [2020-12] nursing_homes_including_rehab_services_archive_12_2020.zip -> NH_QualityMsr_MDS_Nov2020.csv => quality_measures_2020_12.csv
# [2021-01] nursing_homes_including_rehab_services_01_2021.zip -> NH_QualityMsr_MDS_Jan2021.csv => quality_measures_2021_01.csv
# [2021-02] nursing_homes_including_rehab_services_02_2021.zip -> NH_QualityMsr_MDS_Feb2021.csv => quality_measures_2021_02.csv
# [2021-03] nursing_homes_including_rehab_services_03_2021.zip -> NH_QualityMsr_MDS_Mar2021.csv => quality_measures_2021_03.csv
# [2021-04] nursing_homes_including_rehab_services_04_2021.zip -> NH_QualityMsr_MDS_Apr2021.csv => quality_measures_2021_04.csv
# [2021-05] nursing_homes_including_rehab_services_05_2021.zip -> NH_QualityMsr_MDS_May2021.csv => quality_measures_2021_05.csv
# [2021-06] nursing_homes_including_rehab_services_06_2021.zip -> NH_QualityMsr_MDS_Jun2021.csv => quality_measures_2021_06.csv
# [2021-07] nursing_homes_including_rehab_services_07_2021.zip -> NH_QualityMsr_MDS_Jul2021.csv => quality_measures_2021_07.csv
# [2021-08] nursing_homes_including_rehab_services_08_2021.zip -> NH_QualityMsr_MDS_Aug2021.csv => quality_measures_2021_08.csv
# [2021-09] nursing_homes_including_rehab_services_09_2021.zip -> NH_QualityMsr_MDS_Sep2021.csv => quality_measures_2021_09.csv
# [2021-10] nursing_homes_including_rehab_services_10_2021.zip -> NH_QualityMsr_MDS_Oct2021.csv => quality_measures_2021_10.csv
# [2021-11] nursing_homes_including_rehab_services_11_2021.zip -> NH_QualityMsr_MDS_Oct2021.csv => quality_measures_2021_11.csv
# [2021-12] nursing_homes_including_rehab_services_12_2021.zip -> NH_QualityMsr_MDS_Nov2021.csv => quality_measures_2021_12.csv
# [2022-01] nursing_homes_including_rehab_services_01_2022.zip -> NH_QualityMsr_MDS_Jan2022.csv => quality_measures_2022_01.csv
# [2022-02] nursing_homes_including_rehab_services_02_2022.zip -> NH_QualityMsr_MDS_Feb2022.csv => quality_measures_2022_02.csv
# [2022-03] nursing_homes_including_rehab_services_03_2022.zip -> NH_QualityMsr_MDS_Mar2022.csv => quality_measures_2022_03.csv
# [2022-04] nursing_homes_including_rehab_services_04_2022.zip -> NH_QualityMsr_MDS_Apr2022.csv => quality_measures_2022_04.csv
# [2022-05] nursing_homes_including_rehab_services_05_2022.zip -> NH_QualityMsr_MDS_May2022.csv => quality_measures_2022_05.csv
# [2022-06] nursing_homes_including_rehab_services_06_2022.zip -> NH_QualityMsr_MDS_Jun2022.csv => quality_measures_2022_06.csv
# [2022-07] nursing_homes_including_rehab_services_07_2022.zip -> NH_QualityMsr_MDS_Jul2022.csv => quality_measures_2022_07.csv
# [2022-08] nursing_homes_including_rehab_services_08_2022.zip -> NH_QualityMsr_MDS_Aug2022.csv => quality_measures_2022_08.csv
# [2022-09] nursing_homes_including_rehab_services_09_2022.zip -> NH_QualityMsr_MDS_Sep2022.csv => quality_measures_2022_09.csv
# [2022-10] nursing_homes_including_rehab_services_10_2022.zip -> NH_QualityMsr_MDS_Oct2022.csv => quality_measures_2022_10.csv
# [2022-11] nursing_homes_including_rehab_services_11_2022.zip -> NH_QualityMsr_MDS_Oct2022.csv => quality_measures_2022_11.csv
# [2022-12] nursing_homes_including_rehab_services_12_2022.zip -> NH_QualityMsr_MDS_Nov2022.csv => quality_measures_2022_12.csv
# [2023-01] nursing_homes_including_rehab_services_01_2023.zip -> NH_QualityMsr_MDS_Jan2023.csv => quality_measures_2023_01.csv
# [2023-02] nursing_homes_including_rehab_services_02_2023.zip -> NH_QualityMsr_MDS_Feb2023.csv => quality_measures_2023_02.csv
# [2023-03] nursing_homes_including_rehab_services_03_2023.zip -> NH_QualityMsr_MDS_Mar2023.csv => quality_measures_2023_03.csv
# [2023-04] nursing_homes_including_rehab_services_04_2023.zip -> NH_QualityMsr_MDS_Apr2023.csv => quality_measures_2023_04.csv
# [2023-05] nursing_homes_including_rehab_services_05_2023.zip -> NH_QualityMsr_MDS_May2023.csv => quality_measures_2023_05.csv
# [2023-06] nursing_homes_including_rehab_services_06_2023.zip -> NH_QualityMsr_MDS_Jun2023.csv => quality_measures_2023_06.csv
# [2023-07] nursing_homes_including_rehab_services_07_2023.zip -> NH_QualityMsr_MDS_Jul2023.csv => quality_measures_2023_07.csv
# [2023-08] nursing_homes_including_rehab_services_08_2023.zip -> NH_QualityMsr_MDS_Aug2023.csv => quality_measures_2023_08.csv
# [2023-09] nursing_homes_including_rehab_services_09_2023.zip -> NH_QualityMsr_MDS_Sep2023.csv => quality_measures_2023_09.csv
# [2023-10] nursing_homes_including_rehab_services_10_2023.zip -> NH_QualityMsr_MDS_Oct2023.csv => quality_measures_2023_10.csv
# [2023-11] nursing_homes_including_rehab_services_11_2023.zip -> NH_QualityMsr_MDS_Oct2023.csv => quality_measures_2023_11.csv
# [2023-12] nursing_homes_including_rehab_services_12_2023.zip -> NH_QualityMsr_MDS_Nov2023.csv => quality_measures_2023_12.csv
# [2024-01] nursing_homes_including_rehab_services_01_2024.zip -> NH_QualityMsr_MDS_Jan2024.csv => quality_measures_2024_01.csv
# [2024-02] nursing_homes_including_rehab_services_02_2024.zip -> NH_QualityMsr_MDS_Feb2024.csv => quality_measures_2024_02.csv
# [2024-03] nursing_homes_including_rehab_services_03_2024.zip -> NH_QualityMsr_MDS_Mar2024.csv => quality_measures_2024_03.csv
# [2024-04] nursing_homes_including_rehab_services_04_2024.zip -> NH_QualityMsr_MDS_Apr2024.csv => quality_measures_2024_04.csv
# [2024-05] nursing_homes_including_rehab_services_05_2024.zip -> NH_QualityMsr_MDS_May2024.csv => quality_measures_2024_05.csv
# [2024-06] nursing_homes_including_rehab_services_06_2024.zip -> NH_QualityMsr_MDS_Jun2024.csv => quality_measures_2024_06.csv
# [2024-07] nursing_homes_including_rehab_services_07_2024.zip -> NH_QualityMsr_MDS_Jul2024.csv => quality_measures_2024_07.csv
# [2024-08] nursing_homes_including_rehab_services_08_2024.zip -> NH_QualityMsr_MDS_Aug2024.csv => quality_measures_2024_08.csv
# [2024-09] nursing_homes_including_rehab_services_09_2024.zip -> NH_QualityMsr_MDS_Sep2024.csv => quality_measures_2024_09.csv
# [2024-10] nursing_homes_including_rehab_services_10_2024.zip -> NH_QualityMsr_MDS_Oct2024.csv => quality_measures_2024_10.csv
# [2024-11] nursing_homes_including_rehab_services_11_2024.zip -> NH_QualityMsr_MDS_Oct2024.csv => quality_measures_2024_11.csv
# [2024-12] nursing_homes_including_rehab_services_12_2024.zip -> NH_QualityMsr_MDS_Nov2024.csv => quality_measures_2024_12.csv
# [2025-02] nursing_homes_including_rehab_services_02_2025.zip -> NH_QualityMsr_MDS_Feb2025.csv => quality_measures_2025_02.csv
# [2025-03] nursing_homes_including_rehab_services_03_2025.zip -> NH_QualityMsr_MDS_Mar2025.csv => quality_measures_2025_03.csv
# [2025-04] nursing_homes_including_rehab_services_04_2025.zip -> NH_QualityMsr_MDS_Apr2025.csv => quality_measures_2025_04.csv
# [2025-05] nursing_homes_including_rehab_services_05_2025.zip -> NH_QualityMsr_MDS_May2025.csv => quality_measures_2025_05.csv
# [2025-06] nursing_homes_including_rehab_services_06_2025.zip -> NH_QualityMsr_MDS_Jun2025.csv => quality_measures_2025_06.csv
# [2025-07] nursing_homes_including_rehab_services_07_2025.zip -> NH_QualityMsr_MDS_Jul2025.csv => quality_measures_2025_07.csv
#
# [extract] extracted=101, skipped=0
# Processing quality_measures_2025_07.csv
# Processing quality_measures_2025_06.csv
# Processing quality_measures_2025_05.csv
# Processing quality_measures_2025_04.csv
# Processing quality_measures_2025_03.csv
# Processing quality_measures_2025_02.csv
# Processing quality_measures_2024_12.csv
# Processing quality_measures_2024_11.csv
# Processing quality_measures_2024_10.csv
# Processing quality_measures_2024_09.csv
# Processing quality_measures_2024_08.csv
# Processing quality_measures_2024_07.csv
# Processing quality_measures_2024_06.csv
# Processing quality_measures_2024_05.csv
# Processing quality_measures_2024_04.csv
# Processing quality_measures_2024_03.csv
# Processing quality_measures_2024_02.csv
# Processing quality_measures_2024_01.csv
# Processing quality_measures_2023_12.csv
# Processing quality_measures_2023_11.csv
# Processing quality_measures_2023_10.csv
# Processing quality_measures_2023_09.csv
# Processing quality_measures_2023_08.csv
# Processing quality_measures_2023_07.csv
# Processing quality_measures_2023_06.csv
# Processing quality_measures_2023_05.csv
# Processing quality_measures_2023_04.csv
# Processing quality_measures_2023_03.csv
# Processing quality_measures_2023_02.csv
# Processing quality_measures_2023_01.csv
# Processing quality_measures_2022_12.csv
# Processing quality_measures_2022_11.csv
# Processing quality_measures_2022_10.csv
# Processing quality_measures_2022_09.csv
# Processing quality_measures_2022_08.csv
# Processing quality_measures_2022_07.csv
# Processing quality_measures_2022_06.csv
# Processing quality_measures_2022_05.csv
# Processing quality_measures_2022_04.csv
# Processing quality_measures_2022_03.csv
# Processing quality_measures_2022_02.csv
# Processing quality_measures_2022_01.csv
# Processing quality_measures_2021_12.csv
# Processing quality_measures_2021_11.csv
# Processing quality_measures_2021_10.csv
# Processing quality_measures_2021_09.csv
# Processing quality_measures_2021_08.csv
# Processing quality_measures_2021_07.csv
# Processing quality_measures_2021_06.csv
# Processing quality_measures_2021_05.csv
# Processing quality_measures_2021_04.csv
# Processing quality_measures_2021_03.csv
# Processing quality_measures_2021_02.csv
# Processing quality_measures_2021_01.csv
# Processing quality_measures_2020_12.csv
# Processing quality_measures_2020_11.csv
# Processing quality_measures_2020_10.csv
# Processing quality_measures_2020_09.csv
# Processing quality_measures_2020_08.csv
# Processing quality_measures_2020_07.csv
# Processing quality_measures_2020_06.csv
# Processing quality_measures_2020_05.csv
# Processing quality_measures_2020_04.csv
# Processing quality_measures_2020_03.csv
# Processing quality_measures_2020_02.csv
# Processing quality_measures_2020_01.csv
# Processing quality_measures_2019_12.csv
# Processing quality_measures_2019_10.csv
# Processing quality_measures_2019_09.csv
# Processing quality_measures_2019_08.csv
# Processing quality_measures_2019_07.csv
# Processing quality_measures_2019_06.csv
# Processing quality_measures_2019_05.csv
# Processing quality_measures_2019_04.csv
# Processing quality_measures_2019_03.csv
# Processing quality_measures_2019_02.csv
# Processing quality_measures_2019_01.csv
# Processing quality_measures_2018_12.csv
# Processing quality_measures_2018_11.csv
# Processing quality_measures_2018_10.csv
# Processing quality_measures_2018_09.csv
# Processing quality_measures_2018_08.csv
# Processing quality_measures_2018_07.csv
# Processing quality_measures_2018_06.csv
# Processing quality_measures_2018_05.csv
# Processing quality_measures_2018_04.csv
# Processing quality_measures_2018_03.csv
# Processing quality_measures_2018_02.csv
# Processing quality_measures_2018_01.csv
# Processing quality_measures_2017_12.csv
# Processing quality_measures_2017_11.csv
# Processing quality_measures_2017_10.csv
# Processing quality_measures_2017_09.csv
# Processing quality_measures_2017_08.csv
# Processing quality_measures_2017_07.csv
# Processing quality_measures_2017_06.csv
#   Skipping quality_measures_2017_06.csv: no usable score columns in target window
# Processing quality_measures_2017_05.csv
#   Skipping quality_measures_2017_05.csv: no usable score columns in target window
# Processing quality_measures_2017_04.csv
#   Skipping quality_measures_2017_04.csv: no usable score columns in target window
# Processing quality_measures_2017_03.csv
#   Skipping quality_measures_2017_03.csv: no usable score columns in target window
# Processing quality_measures_2017_02.csv
#   Skipping quality_measures_2017_02.csv: no usable score columns in target window
# Processing quality_measures_2017_01.csv
#   Skipping quality_measures_2017_01.csv: no usable score columns in target window
#
# Done.
# Output written to: C:\Repositories\white-bowblis-nhmc\data\interim\quality_measures.csv
# Rows: 450,210
# Columns:
# ['cms_certification_number', 'year', 'quarter', 'qm_401', 'qm_404', 'qm_405', 'qm_406', 'qm_407', 'qm_410', 'qm_419', 'qm_434', 'qm_451', 'qm_452', 'qm_453', 'qm_471']

# %%
# %run quarterly_panel.py
# Out:
# [paths] quality=True  provider_q=True  pbj_q=True  mcr_q=True  chow=True
# [out]   quality_panel=C:\Repositories\white-bowblis-nhmc\data\clean\quality_panel.csv
# [chow] CCNs passing (0/0 or 1/1 within 6m): 7,880
# [filter] drop AK/HI: 219,852 -> 219,247
# [filter] drop beds < 15: 219,247 -> 219,121
# [filter] drop provider_resides_in_hospital==1: 219,121 -> 217,719
# [filter] drop pbj_invalid_quarter==1: 217,719 -> 209,965
# [filter] drop pbj_implausible_hprd==1: 209,965 -> 208,657
# [done] saved quality panel → C:\Repositories\white-bowblis-nhmc\data\clean\quality_panel.csv rows=208,657 cols=86

# %%
#!/usr/bin/env python
# coding: utf-8

from __future__ import annotations

import pandas as pd
import config as cfg

INTERIM = cfg.INTERIM_DIR
OUT = cfg.ensure_dir(cfg.OUTPUTS_DIR / "tables")

CHOW_FP = INTERIM / "chow.csv"

OUT_HCRIS0_NHC1 = OUT / "ccns_hcris0_nhc1.csv"
OUT_HCRIS1_NHC0 = OUT / "ccns_hcris1_nhc0.csv"

chow = pd.read_csv(CHOW_FP, low_memory=False)

chow["cms_certification_number"] = cfg.normalize_ccn_any(
    chow["cms_certification_number"]
)

chow["n_chow_nh_compare"] = (
    pd.to_numeric(chow["n_chow_nh_compare"], errors="coerce")
    .fillna(0)
    .astype(int)
)

chow["n_chow_mcr"] = (
    pd.to_numeric(chow["n_chow_mcr"], errors="coerce")
    .fillna(0)
    .astype(int)
)

# Bucket 1: 0 in HCRIS/MCR, 1 in NHC
hcris0_nhc1 = (
    chow.loc[
        (chow["n_chow_mcr"] == 0) &
        (chow["n_chow_nh_compare"] == 1),
        ["cms_certification_number"]
    ]
    .drop_duplicates()
    .sort_values("cms_certification_number")
    .reset_index(drop=True)
)

# Bucket 2: 1 in HCRIS/MCR, 0 in NHC
hcris1_nhc0 = (
    chow.loc[
        (chow["n_chow_mcr"] == 1) &
        (chow["n_chow_nh_compare"] == 0),
        ["cms_certification_number"]
    ]
    .drop_duplicates()
    .sort_values("cms_certification_number")
    .reset_index(drop=True)
)

hcris0_nhc1.to_csv(OUT_HCRIS0_NHC1, index=False)
hcris1_nhc0.to_csv(OUT_HCRIS1_NHC0, index=False)

print(f"HCRIS = 0, NHC = 1: {len(hcris0_nhc1):,} unique CCNs")
print(f"HCRIS = 1, NHC = 0: {len(hcris1_nhc0):,} unique CCNs")

print("\nSaved:")
print(OUT_HCRIS0_NHC1)
print(OUT_HCRIS1_NHC0)
# Out:
# HCRIS = 0, NHC = 1: 1,874 unique CCNs
# HCRIS = 1, NHC = 0: 499 unique CCNs
#
# Saved:
# C:\Repositories\white-bowblis-nhmc\outputs\tables\ccns_hcris0_nhc1.csv
# C:\Repositories\white-bowblis-nhmc\outputs\tables\ccns_hcris1_nhc0.csv

# %%
#!/usr/bin/env python
# coding: utf-8

from __future__ import annotations

import pandas as pd
import config as cfg

INTERIM = cfg.INTERIM_DIR
OUT = cfg.ensure_dir(cfg.OUTPUTS_DIR / "tables")

# Inputs
SIG_FP = INTERIM / "facility_signatures_long.csv"

HCRIS0_NHC1_FP = OUT / "ccns_hcris0_nhc1.csv"
HCRIS1_NHC0_FP = OUT / "ccns_hcris1_nhc0.csv"

# Outputs
OUT_SIG_HCRIS0_NHC1 = OUT / "facility_signatures_hcris0_nhc1.csv"
OUT_SIG_HCRIS1_NHC0 = OUT / "facility_signatures_hcris1_nhc0.csv"


def read_ccn_list(fp):
    df = pd.read_csv(fp, low_memory=False)

    df["cms_certification_number"] = cfg.normalize_ccn_any(
        df["cms_certification_number"]
    )

    return (
        df[["cms_certification_number"]]
        .dropna()
        .drop_duplicates()
    )


def main():
    signatures = pd.read_csv(SIG_FP, low_memory=False)

    signatures["cms_certification_number"] = cfg.normalize_ccn_any(
        signatures["cms_certification_number"]
    )

    hcris0_nhc1 = read_ccn_list(HCRIS0_NHC1_FP)
    hcris1_nhc0 = read_ccn_list(HCRIS1_NHC0_FP)

    # Bucket 1: 0 in HCRIS/MCR, 1 in NHC
    sig_hcris0_nhc1 = signatures.merge(
        hcris0_nhc1,
        on="cms_certification_number",
        how="inner"
    )

    # Bucket 2: 1 in HCRIS/MCR, 0 in NHC
    sig_hcris1_nhc0 = signatures.merge(
        hcris1_nhc0,
        on="cms_certification_number",
        how="inner"
    )

    sig_hcris0_nhc1 = sig_hcris0_nhc1.sort_values(
        ["cms_certification_number", "group_n"]
    ).reset_index(drop=True)

    sig_hcris1_nhc0 = sig_hcris1_nhc0.sort_values(
        ["cms_certification_number", "group_n"]
    ).reset_index(drop=True)

    sig_hcris0_nhc1.to_csv(OUT_SIG_HCRIS0_NHC1, index=False)
    sig_hcris1_nhc0.to_csv(OUT_SIG_HCRIS1_NHC0, index=False)

    print("[input counts]")
    print(f"HCRIS = 0, NHC = 1 CCNs: {hcris0_nhc1['cms_certification_number'].nunique():,}")
    print(f"HCRIS = 1, NHC = 0 CCNs: {hcris1_nhc0['cms_certification_number'].nunique():,}")

    print("\n[signature rows]")
    print(f"HCRIS = 0, NHC = 1 signature rows: {len(sig_hcris0_nhc1):,}")
    print(f"HCRIS = 1, NHC = 0 signature rows: {len(sig_hcris1_nhc0):,}")

    print("\n[signature CCNs matched]")
    print(f"HCRIS = 0, NHC = 1 matched CCNs: {sig_hcris0_nhc1['cms_certification_number'].nunique():,}")
    print(f"HCRIS = 1, NHC = 0 matched CCNs: {sig_hcris1_nhc0['cms_certification_number'].nunique():,}")

    print("\n[saved]")
    print(OUT_SIG_HCRIS0_NHC1)
    print(OUT_SIG_HCRIS1_NHC0)


if __name__ == "__main__":
    main()
# Out:
# [input counts]
# HCRIS = 0, NHC = 1 CCNs: 1,874
# HCRIS = 1, NHC = 0 CCNs: 499
#
# [signature rows]
# HCRIS = 0, NHC = 1 signature rows: 5,493
# HCRIS = 1, NHC = 0 signature rows: 997
#
# [signature CCNs matched]
# HCRIS = 0, NHC = 1 matched CCNs: 1,874
# HCRIS = 1, NHC = 0 matched CCNs: 499
#
# [saved]
# C:\Repositories\white-bowblis-nhmc\outputs\tables\facility_signatures_hcris0_nhc1.csv
# C:\Repositories\white-bowblis-nhmc\outputs\tables\facility_signatures_hcris1_nhc0.csv
