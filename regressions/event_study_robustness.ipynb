# %%
import pandas as pd
import numpy as np
from diff_diff import CallawaySantAnna, SunAbraham

# ------------------ Paths ------------------
panel_fp = r"C:/Repositories/white-bowblis-nhmc/data/clean/panel.csv"

# ------------------ Load + prep ------------------
df = pd.read_csv(panel_fp)

df["cms_certification_number"] = df["cms_certification_number"].astype(str)

# Parse year_month like "YYYY/MM" or "YYYY-MM" -> datetime at first day of month
ym_clean = df["year_month"].astype(str).str.replace("/", "-", regex=False)
df["ym_date"] = pd.to_datetime(ym_clean + "-01", errors="coerce")
if df["ym_date"].isna().any():
    bad = df.loc[df["ym_date"].isna(), "year_month"].head(10).tolist()
    raise ValueError(f"Could not parse some year_month values. Examples: {bad}")

# Use an integer time index (monotone) for Sun-Abraham relative-time calculations
# This avoids issues with datetimes in some implementations.
df = df.sort_values(["cms_certification_number", "ym_date"]).reset_index(drop=True)
df["t_index"] = (df["ym_date"].dt.year * 12 + df["ym_date"].dt.month).astype(int)

# Safe logs (match your R mk_log)
def mk_log(x):
    x = pd.to_numeric(x, errors="coerce").to_numpy()
    out = np.full_like(x, np.nan, dtype=float)
    mask = x > 0
    out[mask] = np.log(x[mask])
    return out

for y in ["rn_hppd", "lpn_hppd", "cna_hppd", "total_hppd"]:
    if y in df.columns:
        df["ln_" + y.replace("_hppd", "")] = mk_log(df[y])

# ------------------ Baseline chain status (2017Q1) ------------------
if "chain" in df.columns:
    base = (
        df[(df["ym_date"] >= "2017-01-01") & (df["ym_date"] <= "2017-03-31")]
        .sort_values(["cms_certification_number", "ym_date"])
        .groupby("cms_certification_number", as_index=False)["chain"]
        .first()
        .rename(columns={"chain": "baseline_chain_2017Q1"})
    )
    df = df.merge(base, on="cms_certification_number", how="left")
else:
    df["baseline_chain_2017Q1"] = np.nan

# ------------------ Construct first_treat ------------------
# Sun-Abraham needs first_treat:
#   0 for never-treated
#   else the first period when treatment begins
# With your data, we can derive it from post==1 (assuming post stays 1 after treatment)
df["post"] = pd.to_numeric(df["post"], errors="coerce").fillna(0).astype(int)

first_treat_map = (
    df.loc[df["post"] == 1]
      .groupby("cms_certification_number")["t_index"]
      .min()
)

df["first_treat"] = df["cms_certification_number"].map(first_treat_map).fillna(0).astype(int)

# Sanity check: post should be 0 before first_treat and 1 after (if it's a step function)
# If this fails for many units, your 'post' is not a simple adoption indicator.
# We won't hard-fail, but we will warn.
def check_post_step(data, n_check=200):
    samp_units = data["cms_certification_number"].drop_duplicates().head(n_check)
    bad = 0
    for u in samp_units:
        g = data.loc[data["cms_certification_number"] == u].sort_values("t_index")
        ft = int(g["first_treat"].iloc[0])
        if ft == 0:
            continue
        pre = g.loc[g["t_index"] < ft, "post"]
        post = g.loc[g["t_index"] >= ft, "post"]
        if (pre.max() > 0) or (post.min() < 1):
            bad += 1
    if bad > 0:
        print(f"[warn] post is not a clean step function for {bad}/{len(samp_units)} checked units.")
        print("       If this is large, we should build first_treat from your true treatment-date column instead.")

check_post_step(df)

# ------------------ Define subsets (match your R) ------------------
is_prepand  = (df["ym_date"] >= "2017-01-01") & (df["ym_date"] <= "2019-12-31")
is_pandemic = (df["ym_date"] >= "2020-04-01") & (df["ym_date"] <= "2024-06-30")

datasets = {
    "full_with_anticipation": df.copy(),
    "full_without_anticipation": df.loc[df.get("anticipation2", 0) == 0].copy(),
    "prepandemic_wo": df.loc[is_prepand & (df.get("anticipation2", 0) == 0)].copy(),
    "pandemic_wo": df.loc[is_pandemic & (df.get("anticipation2", 0) == 0)].copy(),
    "baseline_chain_2017q1_wo": df.loc[(df["baseline_chain_2017Q1"] == 1) & (df.get("anticipation2", 0) == 0)].copy(),
    "baseline_nonchain_2017q1_wo": df.loc[(df["baseline_chain_2017Q1"] == 0) & (df.get("anticipation2", 0) == 0)].copy(),
}

outs_order = ["rn_hppd", "lpn_hppd", "cna_hppd", "total_hppd"]
log_outs   = ["ln_rn", "ln_lpn", "ln_cna", "ln_total"]

# ------------------ Sun-Abraham runner ------------------
def run_sa(data: pd.DataFrame, outcome: str, label: str, bootstrap: bool = False):
    d = data.dropna(subset=[outcome, "cms_certification_number", "t_index", "first_treat"]).copy()
    if d.empty:
        print(f"[skip] {label}: outcome={outcome} has no usable observations.")
        return None

    # Restrict event window to reduce matrix size
    d["event_time"] = np.where(d["first_treat"] > 0, d["t_index"] - d["first_treat"], np.nan)
    E_MIN, E_MAX = -5, 5
    d = d[(d["first_treat"] == 0) | (d["event_time"].between(E_MIN, E_MAX))].copy()

    if bootstrap:
        sa = SunAbraham(
            control_group="never_treated",
            anticipation=0,
            n_bootstrap=999,
            bootstrap_weights="rademacher",
            seed=42,
            cluster="cms_certification_number"
        )
    else:
        sa = SunAbraham(
            control_group="never_treated",
            anticipation=0,
            cluster="cms_certification_number"
        )

    treated = d.loc[d["first_treat"] > 0, "first_treat"]
    print("Unique cohorts:", treated.nunique())
    print("Event-time range:", int(d["event_time"].min()), int(d["event_time"].max()))

    results = sa.fit(
        d,
        outcome=outcome,
        unit="cms_certification_number",
        time="t_index",
        first_treat="first_treat"
    )

    print("\n" + "=" * 90)
    print(f"{label} | outcome = {outcome} | N = {len(d):,} | units = {d['cms_certification_number'].nunique():,}")
    print("=" * 90)
    results.print_summary()
    return results

# ------------------ Run everything ------------------
BOOTSTRAP = False  # set True if you want bootstrap inference

all_results = {}

for dname, dset in datasets.items():
    all_results[dname] = {"levels": {}, "logs": {}}

    # Levels
    for y in outs_order:
        if y in dset.columns:
            all_results[dname]["levels"][y] = run_sa(dset, y, label=dname, bootstrap=BOOTSTRAP)

    # Logs (only if exist)
    for y in log_outs:
        if y in dset.columns:
            all_results[dname]["logs"][y] = run_sa(dset, y, label=dname, bootstrap=BOOTSTRAP)

print("\nDone.")
# Out:
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = rn_hppd | N = 517,197 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                517197
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0143       0.0061     -2.334     0.0196      *
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0263, -0.0023]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0203       0.0067      3.024     0.0025     **
# -4                    0.0128       0.0065      1.966     0.0493      *
# -3                    0.0081       0.0058      1.392     0.1639
# -2                    0.0004       0.0056      0.075     0.9403
# 0                    -0.0133       0.0058     -2.313     0.0207      *
# 1                    -0.0129       0.0061     -2.135     0.0328      *
# 2                    -0.0134       0.0064     -2.103     0.0355      *
# 3                    -0.0186       0.0067     -2.794     0.0052     **
# 4                    -0.0141       0.0069     -2.041     0.0412      *
# 5                    -0.0137       0.0070     -1.976     0.0481      *
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = lpn_hppd | N = 517,197 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                517197
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0048       0.0072     -0.676     0.4992
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0189, 0.0092]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                   -0.0031       0.0073     -0.416     0.6774
# -4                   -0.0068       0.0071     -0.958     0.3381
# -3                   -0.0077       0.0071     -1.083     0.2787
# -2                   -0.0063       0.0067     -0.932     0.3511
# 0                    -0.0076       0.0071     -1.080     0.2802
# 1                    -0.0051       0.0076     -0.666     0.5051
# 2                     0.0044       0.0083      0.535     0.5929
# 3                    -0.0074       0.0075     -0.981     0.3265
# 4                    -0.0061       0.0080     -0.762     0.4458
# 5                    -0.0073       0.0081     -0.903     0.3665
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = cna_hppd | N = 517,197 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                517197
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0127       0.0112     -1.142     0.2536
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0346, 0.0091]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0226       0.0122      1.847     0.0647      .
# -4                    0.0194       0.0120      1.616     0.1062
# -3                    0.0071       0.0124      0.574     0.5659
# -2                   -0.0048       0.0123     -0.387     0.6991
# 0                    -0.0182       0.0106     -1.717     0.0859      .
# 1                    -0.0195       0.0113     -1.731     0.0835      .
# 2                    -0.0089       0.0124     -0.724     0.4688
# 3                    -0.0184       0.0124     -1.484     0.1379
# 4                    -0.0028       0.0127     -0.223     0.8237
# 5                    -0.0076       0.0131     -0.582     0.5604
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = total_hppd | N = 517,197 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                517197
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0319       0.0169     -1.891     0.0587      .
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0650, 0.0012]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0398       0.0181      2.200     0.0278      *
# -4                    0.0254       0.0179      1.419     0.1558
# -3                    0.0075       0.0181      0.415     0.6783
# -2                   -0.0106       0.0184     -0.576     0.5646
# 0                    -0.0392       0.0164     -2.395     0.0166      *
# 1                    -0.0375       0.0172     -2.177     0.0295      *
# 2                    -0.0179       0.0190     -0.944     0.3451
# 3                    -0.0443       0.0184     -2.406     0.0161      *
# 4                    -0.0230       0.0190     -1.211     0.2258
# 5                    -0.0287       0.0193     -1.485     0.1375
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = ln_rn | N = 512,767 | units = 7,802
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                512767
# Treated units:                       1558
# Control units:                       6244
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0112       0.0185     -0.605     0.5455
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0475, 0.0251]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0860       0.0217      3.957     0.0001    ***
# -4                    0.0676       0.0203      3.323     0.0009    ***
# -3                    0.0514       0.0188      2.727     0.0064     **
# -2                    0.0259       0.0184      1.405     0.1601
# 0                    -0.0239       0.0171     -1.401     0.1613
# 1                    -0.0187       0.0188     -0.994     0.3202
# 2                    -0.0048       0.0198     -0.240     0.8105
# 3                    -0.0210       0.0210     -0.999     0.3178
# 4                    -0.0024       0.0217     -0.113     0.9103
# 5                     0.0052       0.0225      0.230     0.8183
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = ln_lpn | N = 513,936 | units = 7,791
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                513936
# Treated units:                       1559
# Control units:                       6232
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                   0.0081       0.0101      0.807     0.4199
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0116, 0.0279]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0104       0.0111      0.935     0.3500
# -4                    0.0052       0.0106      0.491     0.6233
# -3                    0.0076       0.0101      0.747     0.4551
# -2                    0.0081       0.0098      0.828     0.4076
# 0                     0.0021       0.0092      0.228     0.8198
# 1                     0.0066       0.0101      0.649     0.5160
# 2                     0.0161       0.0109      1.479     0.1392
# 3                     0.0084       0.0115      0.730     0.4652
# 4                     0.0080       0.0121      0.665     0.5061
# 5                     0.0080       0.0122      0.660     0.5089
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = ln_cna | N = 517,090 | units = 7,803
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                517090
# Treated units:                       1559
# Control units:                       6244
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0026       0.0056     -0.469     0.6394
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0137, 0.0084]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0162       0.0063      2.594     0.0095     **
# -4                    0.0134       0.0063      2.134     0.0328      *
# -3                    0.0070       0.0063      1.127     0.2599
# -2                    0.0001       0.0062      0.020     0.9837
# 0                    -0.0072       0.0054     -1.353     0.1759
# 1                    -0.0064       0.0058     -1.093     0.2746
# 2                    -0.0010       0.0062     -0.165     0.8686
# 3                    -0.0051       0.0064     -0.802     0.4225
# 4                     0.0032       0.0065      0.491     0.6235
# 5                     0.0014       0.0067      0.202     0.8398
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_with_anticipation | outcome = ln_total | N = 517,197 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                517197
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0066       0.0050     -1.322     0.1863
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0163, 0.0032]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0177       0.0055      3.206     0.0013     **
# -4                    0.0121       0.0055      2.208     0.0272      *
# -3                    0.0061       0.0055      1.110     0.2670
# -2                   -0.0017       0.0056     -0.297     0.7664
# 0                    -0.0101       0.0047     -2.122     0.0339      *
# 1                    -0.0086       0.0051     -1.696     0.0900      .
# 2                    -0.0031       0.0055     -0.571     0.5682
# 3                    -0.0099       0.0055     -1.785     0.0742      .
# 4                    -0.0026       0.0057     -0.456     0.6481
# 5                    -0.0047       0.0058     -0.808     0.4190
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = rn_hppd | N = 513,216 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                513216
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0142       0.0060     -2.367     0.0179      *
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0260, -0.0024]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0201       0.0066      3.035     0.0024     **
# -4                   -0.0310       0.0285     -1.084     0.2782
# -3                    0.0260       0.0473      0.550     0.5821
# -2                   -0.0416       0.0242     -1.719     0.0855      .
# 0                    -0.0132       0.0057     -2.328     0.0199      *
# 1                    -0.0127       0.0059     -2.128     0.0333      *
# 2                    -0.0134       0.0062     -2.149     0.0316      *
# 3                    -0.0185       0.0065     -2.833     0.0046     **
# 4                    -0.0141       0.0068     -2.088     0.0368      *
# 5                    -0.0137       0.0068     -2.005     0.0450      *
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = lpn_hppd | N = 513,216 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                513216
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0041       0.0073     -0.561     0.5749
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0184, 0.0102]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                   -0.0049       0.0073     -0.676     0.4992
# -4                    0.0174       0.0397      0.437     0.6621
# -3                    0.0385       0.0288      1.337     0.1813
# -2                    0.1046       0.0310      3.376     0.0007    ***
# 0                    -0.0073       0.0071     -1.020     0.3077
# 1                    -0.0047       0.0076     -0.621     0.5343
# 2                     0.0049       0.0083      0.588     0.5564
# 3                    -0.0062       0.0077     -0.811     0.4175
# 4                    -0.0049       0.0081     -0.607     0.5437
# 5                    -0.0062       0.0083     -0.750     0.4532
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = cna_hppd | N = 513,216 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                513216
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0150       0.0113     -1.329     0.1838
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0370, 0.0071]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0254       0.0125      2.036     0.0417      *
# -4                   -0.0630       0.0516     -1.221     0.2220
# -3                   -0.3550       0.0624     -5.686     0.0000    ***
# -2                   -0.0772       0.0587     -1.316     0.1883
# 0                    -0.0210       0.0108     -1.952     0.0510      .
# 1                    -0.0221       0.0114     -1.940     0.0523      .
# 2                    -0.0111       0.0124     -0.899     0.3686
# 3                    -0.0203       0.0125     -1.625     0.1041
# 4                    -0.0050       0.0128     -0.389     0.6974
# 5                    -0.0094       0.0132     -0.710     0.4776
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = total_hppd | N = 513,216 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                513216
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0333       0.0171     -1.951     0.0510      .
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0667, 0.0001]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0406       0.0182      2.231     0.0257      *
# -4                   -0.0766       0.0804     -0.953     0.3406
# -3                   -0.2905       0.0787     -3.693     0.0002    ***
# -2                   -0.0142       0.0823     -0.172     0.8633
# 0                    -0.0415       0.0165     -2.509     0.0121      *
# 1                    -0.0395       0.0173     -2.278     0.0228      *
# 2                    -0.0197       0.0190     -1.036     0.3002
# 3                    -0.0450       0.0186     -2.415     0.0158      *
# 4                    -0.0240       0.0192     -1.253     0.2103
# 5                    -0.0292       0.0195     -1.496     0.1347
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = ln_rn | N = 508,831 | units = 7,802
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                508831
# Treated units:                       1558
# Control units:                       6244
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0148       0.0181     -0.821     0.4115
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0502, 0.0206]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0862       0.0205      4.209     0.0000    ***
# -4                    0.2814       0.0973      2.892     0.0038     **
# -3                    0.2249       0.1232      1.825     0.0680      .
# -2                    0.0188       0.0916      0.205     0.8375
# 0                    -0.0273       0.0167     -1.631     0.1030
# 1                    -0.0220       0.0184     -1.199     0.2305
# 2                    -0.0091       0.0194     -0.470     0.6387
# 3                    -0.0251       0.0205     -1.224     0.2211
# 4                    -0.0052       0.0211     -0.247     0.8048
# 5                     0.0012       0.0220      0.054     0.9569
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = ln_lpn | N = 509,963 | units = 7,790
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                509963
# Treated units:                       1558
# Control units:                       6232
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                   0.0072       0.0100      0.713     0.4759
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0125, 0.0268]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0067       0.0110      0.604     0.5459
# -4                    0.0332       0.0477      0.695     0.4871
# -3                   -0.0031       0.0713     -0.044     0.9652
# -2                   -0.0614       0.0420     -1.463     0.1436
# 0                     0.0011       0.0091      0.121     0.9040
# 1                     0.0050       0.0100      0.500     0.6170
# 2                     0.0148       0.0108      1.363     0.1728
# 3                     0.0079       0.0114      0.687     0.4920
# 4                     0.0075       0.0120      0.623     0.5335
# 5                     0.0072       0.0121      0.594     0.5525
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = ln_cna | N = 513,109 | units = 7,803
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                513109
# Treated units:                       1559
# Control units:                       6244
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0042       0.0057     -0.740     0.4591
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0153, 0.0069]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0177       0.0064      2.788     0.0053     **
# -4                   -0.0325       0.0246     -1.322     0.1862
# -3                   -0.3063       0.0358     -8.557     0.0000    ***
# -2                   -0.1819       0.0315     -5.782     0.0000    ***
# 0                    -0.0090       0.0054     -1.676     0.0938      .
# 1                    -0.0081       0.0058     -1.386     0.1657
# 2                    -0.0026       0.0062     -0.410     0.6818
# 3                    -0.0065       0.0064     -1.010     0.3125
# 4                     0.0016       0.0065      0.249     0.8033
# 5                     0.0001       0.0067      0.008     0.9933
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 88
# Event-time range: -5 5
#
# ==========================================================================================
# full_without_anticipation | outcome = ln_total | N = 513,216 | units = 7,806
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                513216
# Treated units:                       1559
# Control units:                       6247
# Treatment cohorts:                     88
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0074       0.0049     -1.498     0.1342
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0171, 0.0023]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0177       0.0055      3.242     0.0012     **
# -4                   -0.0249       0.0215     -1.158     0.2470
# -3                   -0.1757       0.0295     -5.961     0.0000    ***
# -2                   -0.1535       0.0253     -6.065     0.0000    ***
# 0                    -0.0111       0.0047     -2.343     0.0191      *
# 1                    -0.0096       0.0050     -1.892     0.0584      .
# 2                    -0.0040       0.0054     -0.737     0.4611
# 3                    -0.0106       0.0055     -1.911     0.0560      .
# 4                    -0.0034       0.0057     -0.609     0.5426
# 5                    -0.0054       0.0058     -0.929     0.3528
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 39
# Event-time range: -5 5
# C:\Users\Owner\anaconda3\Lib\site-packages\diff_diff\linalg.py:1151: UserWarning: Rank-deficient design matrix: dropping 2 of 235 columns (column 230, column 233). Coefficients for these columns are set to NA. This may indicate multicollinearity in your model specification.
#   coefficients, residuals, fitted, vcov = solve_ols(
# ==========================================================================================
# prepandemic_wo | outcome = rn_hppd | N = 207,843 | units = 6,857
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                207843
# Treated units:                        755
# Control units:                       6102
# Treatment cohorts:                     39
# Time periods:                          36
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0203       0.0068     -2.972     0.0030     **
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0337, -0.0069]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                       nan          nan      0.000     1.0000
# -4                       nan          nan      0.000     1.0000
# -2                   -0.0134       0.0196     -0.680     0.4963
# 0                    -0.0154       0.0056     -2.744     0.0061     **
# 1                    -0.0129       0.0061     -2.131     0.0331      *
# 2                    -0.0148       0.0076     -1.946     0.0517      .
# 3                    -0.0259       0.0084     -3.099     0.0019     **
# 4                    -0.0286       0.0087     -3.266     0.0011     **
# 5                    -0.0271       0.0090     -2.994     0.0028     **
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 39
# Event-time range: -5 5
# C:\Users\Owner\anaconda3\Lib\site-packages\diff_diff\linalg.py:1151: UserWarning: Rank-deficient design matrix: dropping 2 of 235 columns (column 230, column 233). Coefficients for these columns are set to NA. This may indicate multicollinearity in your model specification.
#   coefficients, residuals, fitted, vcov = solve_ols(
# ...
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                210613
# Treated units:                        428
# Control units:                       2533
# Treatment cohorts:                     85
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                   0.0126       0.0623      0.203     0.8394
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.1095, 0.1347]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.1195       0.0316      3.782     0.0002    ***
# -4                   -0.0764       0.0383     -1.995     0.0460      *
# -2                    0.9438       0.0930     10.147     0.0000    ***
# 0                     0.0163       0.0605      0.269     0.7881
# 1                     0.0084       0.0622      0.135     0.8924
# 2                     0.0269       0.0631      0.426     0.6703
# 3                     0.0099       0.0631      0.156     0.8757
# 4                     0.0137       0.0637      0.215     0.8301
# 5                    -0.0003       0.0654     -0.005     0.9961
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 85
# Event-time range: -5 5
#
# ==========================================================================================
# baseline_nonchain_2017q1_wo | outcome = total_hppd | N = 210,613 | units = 2,961
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                210613
# Treated units:                        428
# Control units:                       2533
# Treatment cohorts:                     85
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0092       0.0824     -0.111     0.9113
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.1706, 0.1523]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.1689       0.0441      3.830     0.0001    ***
# -4                    0.0003       0.0551      0.005     0.9957
# -2                    1.3274       0.2127      6.240     0.0000    ***
# 0                    -0.0100       0.0800     -0.125     0.9009
# 1                    -0.0123       0.0821     -0.149     0.8814
# 2                     0.0163       0.0838      0.195     0.8456
# 3                    -0.0130       0.0841     -0.155     0.8768
# 4                    -0.0152       0.0849     -0.179     0.8578
# 5                    -0.0221       0.0858     -0.258     0.7967
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 85
# Event-time range: -5 5
#
# ==========================================================================================
# baseline_nonchain_2017q1_wo | outcome = ln_rn | N = 208,665 | units = 2,961
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                208665
# Treated units:                        428
# Control units:                       2533
# Treatment cohorts:                     85
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                   0.0029       0.0904      0.032     0.9743
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.1742, 0.1801]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.1890       0.0447      4.225     0.0000    ***
# -4                    0.3976       0.0630      6.315     0.0000    ***
# -2                    0.5217       0.0733      7.119     0.0000    ***
# 0                    -0.0179       0.0878     -0.204     0.8384
# 1                    -0.0161       0.0899     -0.179     0.8578
# 2                     0.0046       0.0910      0.050     0.9601
# 3                     0.0023       0.0917      0.026     0.9796
# 4                     0.0097       0.0931      0.104     0.9172
# 5                     0.0397       0.0961      0.413     0.6795
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 85
# Event-time range: -5 5
#
# ==========================================================================================
# baseline_nonchain_2017q1_wo | outcome = ln_lpn | N = 209,167 | units = 2,957
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                209167
# Treated units:                        428
# Control units:                       2529
# Treatment cohorts:                     85
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0056       0.0530     -0.105     0.9165
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.1094, 0.0983]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0053       0.0272      0.194     0.8463
# -4                    0.0753       0.0336      2.244     0.0248      *
# -2                    0.1339       0.0875      1.529     0.1262
# 0                    -0.0165       0.0508     -0.325     0.7453
# 1                    -0.0076       0.0525     -0.145     0.8845
# 2                     0.0019       0.0540      0.035     0.9717
# 3                    -0.0012       0.0540     -0.023     0.9820
# 4                    -0.0060       0.0546     -0.110     0.9124
# 5                    -0.0027       0.0559     -0.049     0.9612
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 85
# Event-time range: -5 5
#
# ==========================================================================================
# baseline_nonchain_2017q1_wo | outcome = ln_cna | N = 210,576 | units = 2,961
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                210576
# Treated units:                        428
# Control units:                       2533
# Treatment cohorts:                     85
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                   0.0055       0.0302      0.182     0.8554
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0536, 0.0646]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0609       0.0153      3.991     0.0001    ***
# -4                   -0.0457       0.0207     -2.205     0.0275      *
# -2                    0.2367       0.0411      5.754     0.0000    ***
# 0                     0.0034       0.0293      0.116     0.9075
# 1                     0.0013       0.0303      0.042     0.9661
# 2                     0.0103       0.0306      0.336     0.7366
# 3                     0.0059       0.0307      0.193     0.8472
# 4                     0.0079       0.0309      0.256     0.7976
# 5                     0.0046       0.0317      0.144     0.8852
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
# Unique cohorts: 85
# Event-time range: -5 5
#
# ==========================================================================================
# baseline_nonchain_2017q1_wo | outcome = ln_total | N = 210,613 | units = 2,961
# ==========================================================================================
# =====================================================================================
#                   Sun-Abraham Interaction-Weighted Estimator Results
# =====================================================================================
#
# Total observations:                210613
# Treated units:                        428
# Control units:                       2533
# Treatment cohorts:                     85
# Time periods:                          90
# Control group:                 never_treated
#
# -------------------------------------------------------------------------------------
#                    Overall Average Treatment Effect on the Treated
# -------------------------------------------------------------------------------------
# Parameter           Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# ATT                  -0.0064       0.0243     -0.264     0.7918
# -------------------------------------------------------------------------------------
#
# 95% Confidence Interval: [-0.0540, 0.0412]
#
# -------------------------------------------------------------------------------------
#                             Event Study (Dynamic) Effects
# -------------------------------------------------------------------------------------
# Rel. Period         Estimate    Std. Err.     t-stat      P>|t|   Sig.
# -------------------------------------------------------------------------------------
# -5                    0.0543       0.0128      4.238     0.0000    ***
# -4                   -0.0056       0.0183     -0.306     0.7599
# -2                    0.2216       0.0523      4.236     0.0000    ***
# 0                    -0.0073       0.0236     -0.309     0.7575
# 1                    -0.0073       0.0242     -0.303     0.7621
# 2                    -0.0014       0.0247     -0.055     0.9562
# 3                    -0.0065       0.0248     -0.262     0.7933
# 4                    -0.0076       0.0251     -0.301     0.7632
# 5                    -0.0085       0.0254     -0.336     0.7368
# -------------------------------------------------------------------------------------
#
# Signif. codes: '***' 0.001, '**' 0.01, '*' 0.05, '.' 0.1
# =====================================================================================
#
# Done.
